# %% [markdown]
# <a href="https://colab.research.google.com/github/Tokollo-server/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Scoring.
# I am treating this lane as a scoring problem because the model should assign each candidate item a numeric value that helps rank results for the search decay pipeline. The score supports a downstream decision: which items belong near the top of the ranked list.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# quick check: what task type am I using?
task_type = "scoring"
task_type
# Out:
# 'scoring'

# %% [markdown]
# ## 2. Target or proxy
#
# *I would predict a relevance-style proxy label derived from observed search behavior or curriculum-defined outcomes. The label is not a hand-written rule; it comes from measured result quality in the data, which makes it a usable target for learning.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
target_name = "relevance_proxy"
target_name
# Out:
# 'relevance_proxy'

# %% [markdown]
# ## 3. Success metric
#
# *My main success metric is Precision@50. That is the clearest metric here because the curriculum already defines a target benchmark, and the model’s output is meant to improve the quality of the top-50 results.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
metric_name = "Precision@50"
baseline = 0.24
target = 0.74

metric_name, baseline, target
# Out:
# ('Precision@50', 0.24, 0.74)

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *One row = one content item.
# I am using the content-level table because each row contains one content_id with its content type, intent, CTR, and average position. That makes the unit of analysis concrete and matches the scoring frame.

# %%
# !git clone https://github.com/Tokollo-server/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# !ls
# !ls data/raw
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
df.head()
df.shape, df.columns.tolist()
df[["content_id", "client_id", "content_type", "main_intent", "ctr", "avg_position"]].head()
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
df[["content_id", "client_id", "content_type", "main_intent", "ctr", "avg_position"]].head()


# %cd /content/flyrank-ml-internship
# !ls
# !ls data/raw
# !grep -RniE "Precision@50|0.74|0.26|Random Forest|baseline|train_test|GroupShuffle|split" \
README.md docs scripts work skills 2>/dev/null

# !grep -RniE "precision|average_precision|train_test_split|GroupShuffleSplit|fit\(|predict\(" \
scripts work 2>/dev/null
# %cd /content/flyrank-ml-internship
# !sed -n '228,246p' docs/ml-intern-dataset-and-lane-guide.md
# !sed -n '55,90p' scripts/02_baseline_score.py
# !sed -n '70,110p' scripts/03_train_model.py
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

content_view = df[
    [
        "content_id",
        "client_id",
        "content_type",
        "main_intent",
        "ctr",
        "avg_position",
        "trend_direction",
        "trend_pct"
    ]
].head()

content_view
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df["is_decaying"] = (
    df["trend_direction"]
    .astype("string")
    .str.lower()
    .eq("down")
    .astype(int)
)

content_view = df[
    [
        "content_id",
        "client_id",
        "content_type",
        "main_intent",
        "ctr",
        "avg_position",
        "trend_direction",
        "trend_pct",
        "is_decaying",
    ]
].head()

content_view
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.
# /content/flyrank-ml-internship/flyrank-ml-internship
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission
# content_refresh_anonymized.csv
# /content/flyrank-ml-internship
# AGENTS.md    docs		    notebooks	      scripts	  work
# CLAUDE.md    flyrank-ml-internship  outputs	      SETUP.md
# data	     GUIDE.md		    README.md	      skills
# DATA_USE.md  LICENSE		    requirements.txt  submission
# content_refresh_anonymized.csv
# README.md:54:| 4 | ML-07 | `w04_baseline_score` | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tokollo-server/flyrank-ml-internship/blob/main/work/notebooks/w04_baseline_score.ipynb?flush_cache=true) |
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *A fixed rule would be too brittle because relevance depends on multiple signals at once: the query, the content, the context, and the observed outcome. ML is better because it can learn a weighted pattern from examples instead of relying on one hard-coded if-statement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
rule_reason = "The pattern is too mixed for a single fixed rule."
rule_reason
# Out:
# 'The pattern is too mixed for a single fixed rule.'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
